# %%
# Steps
# Run the prediction model with just latitude and longitude
# Create grid of latitude and longitude spaced out
# Run the prediction model on the grid
# Plot the results on a heatmap overlaid over a map
